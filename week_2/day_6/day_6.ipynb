# %% [markdown]
# # Day 6: The Shape of the Problem
#
# ## Exercise 1: Build - Baseline Model
# Build a model that predicts "no breach" every time and report its accuracy.

# %%
import pandas as pd
from sklearn.metrics import confusion_matrix, precision_score, recall_score, f1_score

# Load data
df = pd.read_csv("incidents.csv")

# Your baseline model code here

# %% [markdown]
# ## Exercise 2: Build - 150-Word Analysis
# Why is a 96%-accurate model entirely worthless? Which metric should you present to a delivery manager?

# %% [markdown]
# Your 150-word analysis here...

# %% [markdown]
# ## Exercise 3: Probe
# For SLA breach prediction, is a false positive or false negative more expensive? Defend your answer in operational terms.

# %% [markdown]
# Your probe answer here...
